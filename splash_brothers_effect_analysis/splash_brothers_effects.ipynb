# %% [markdown]
# # Splash Brothers Effect

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### How

# %%
players = pd.read_csv('../dataset/players_preprocess.csv')

# %%
players
# Out:
#        Unnamed: 0          Player Pos  Age   Tm                  Team   G  \
# 0               0      A.C. Green  PF   22  LAL    Los Angeles Lakers  82
# 1               1      A.C. Green  PF   23  LAL    Los Angeles Lakers  79
# 2               2      A.C. Green  PF   24  LAL    Los Angeles Lakers  82
# 3               3      A.C. Green  PF   25  LAL    Los Angeles Lakers  82
# 4               4      A.C. Green  PF   26  LAL    Los Angeles Lakers  82
# ...           ...             ...  ..  ...  ...                   ...  ..
# 18239       18239  Željko Rebrača   C   29  DET       Detroit Pistons  74
# 18240       18240  Željko Rebrača   C   30  DET       Detroit Pistons  30
# 18241       18241  Željko Rebrača   C   31  ATL         Atlanta Hawks  24
# 18242       18242  Željko Rebrača   C   32  LAC  Los Angeles Clippers  58
# 18243       18243  Željko Rebrača   C   33  LAC  Los Angeles Clippers  29
#
#          GS    MP   FG  ...  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS  \
# ...

# %%
players[players['Player'] == "Stephen Curry"][['Year','3P','3PA']]
# Out:
#        Year   3P   3PA
# 16018  2010  2.1   4.8
# 16019  2011  2.0   4.6
# 16020  2012  2.1   4.7
# 16021  2013  3.5   7.7
# 16022  2014  3.3   7.9
# 16023  2015  3.6   8.1
# 16024  2016  5.1  11.2
# 16025  2017  4.1  10.0
# 16026  2018  4.2   9.8
# 16027  2019  5.1  11.7
# 16028  2020  2.4   9.8
# 16029  2021  5.3  12.7
# 16030  2022  4.5  11.7

# %%
curry_3p = players[players['Player'] == "Stephen Curry"][['Year','3P','3PA']]

# %%
plt.plot(curry_3p['Year'], curry_3p['3P'])

# %%
players[players['Player'] == "Klay Thompson"][['Year','3P','3PA']]
# Out:
#        Year   3P  3PA
# 10322  2012  1.7  4.1
# 10323  2013  2.6  6.4
# 10324  2014  2.8  6.6
# 10325  2015  3.1  7.1
# 10326  2016  3.5  8.1
# 10327  2017  3.4  8.3
# 10328  2018  3.1  7.1
# 10329  2019  3.1  7.7
# 10330  2022  3.6  9.3

# %%
klay_3p = players[players['Player'] == "Klay Thompson"][['Year','3P','3PA']]

# %%
klay_3p['3P']
# Out:
# 10322    1.7
# 10323    2.6
# 10324    2.8
# 10325    3.1
# 10326    3.5
# 10327    3.4
# 10328    3.1
# 10329    3.1
# 10330    3.6
# Name: 3P, dtype: float64

# %%
plt.plot(klay_3p['Year'], klay_3p['3P'])
